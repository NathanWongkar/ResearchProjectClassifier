# %% [markdown]
# # Install and Import Dependancies

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Collecting torch
#   Using cached torch-1.13.1-cp310-none-macosx_11_0_arm64.whl (53.2 MB)
# Collecting torchvision
#   Using cached torchvision-0.14.1-cp310-cp310-macosx_11_0_arm64.whl (1.3 MB)
# Collecting torchaudio
#   Downloading torchaudio-0.13.1-cp310-cp310-macosx_12_0_arm64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 6.3 MB/s eta 0:00:0000:0100:01
# Collecting typing-extensions
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torchvision) (9.0.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torchvision) (1.23.3)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->torchvision) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->torchvision) (2021.10.8)
# Installing collected packages: typing-extensions, torch, torchvision, torchaudio
# Successfully installed torch-1.13.1 torchaudio-0.13.1 torchvision-0.14.1 typing-extensions-4.4.0
#
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: pip3 install --upgrade pip

# %% [markdown]
# # Load Model

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15078, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 15078 (delta 0), reused 0 (delta 0), pack-reused 15075
# Receiving objects: 100% (15078/15078), 14.06 MiB | 19.58 MiB/s, done.
# Resolving deltas: 100% (10338/10338), done.

# %%
# !cd yolov5/ && pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.1.30)
# Requirement already satisfied: ipython in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (8.9.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (3.6.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (1.23.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (4.7.0.68)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (9.4.0)
# Requirement already satisfied: psutil in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (5.9.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (1.10.0)
# Requirement already satisfied: thop>=0.1.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.7.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (1.13.1)
# Requirement already satisfied: torchvision>=0.8.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (0.14.1)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (4.64.0)
# Requirement already satisfied: tensorboard>=2.4.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (2.11.2)
# Requirement already satisfied: pandas>=1.1.4 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from gitpython->-r requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: decorator in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (3.0.36)
# Requirement already satisfied: traitlets>=5 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: backcall in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (0.18.2)
# Requirement already satisfied: pygments>=2.4.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (2.14.0)
# Requirement already satisfied: stack-data in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (0.6.2)
# Requirement already satisfied: appnope in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (0.1.3)
# Requirement already satisfied: pickleshare in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: cycler>=0.10 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (4.38.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (3.3)
# Requirement already satisfied: typing-extensions in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from torch>=1.7.0->-r requirements.txt (line 16)) (4.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (2.2.2)
# Requirement already satisfied: wheel>=0.26 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.37.1)
# Requirement already satisfied: absl-py>=0.4 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.4.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (65.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.51.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (3.20.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (2.16.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2022.7.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython->-r requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from pexpect>4.3->ipython->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->-r requirements.txt (line 6)) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r requirements.txt (line 22)) (2.1.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from stack-data->ipython->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from stack-data->ipython->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from stack-data->ipython->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/nathanwong/miniforge3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 22)) (3.2.2)

# %% [markdown]
# ## Installing Requirements

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/nathanwong/Desktop/Yale NUS/ResearchProject/ResearchProjectClassifier/ImageClassifierTest.ipynb Cell 7 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/nathanwong/Desktop/Yale%20NUS/ResearchProject/ResearchProjectClassifier/ImageClassifierTest.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> from matplotlib import pyplot as plt
#       <a href='vscode-notebook-cell:/Users/nathanwong/Desktop/Yale%20NUS/ResearchProject/ResearchProjectClassifier/ImageClassifierTest.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/Users/nathanwong/Desktop/Yale%20NUS/ResearchProject/ResearchProjectClassifier/ImageClassifierTest.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1454, in HTTPSConnection.connect(self)
#    1452     server_hostname = self.host
# -> 1454 self.sock = self._context.wrap_socket(self.sock,
#    1455                                       server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:512, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     506 def wrap_socket(self, sock, server_side=False,
#     507                 do_handshake_on_connect=True,
#     508                 suppress_ragged_eofs=True,
#     509                 server_hostname=None, session=None):
#     510     # SSLSocket class handles server_hostname encoding before it calls
#     511     # ctx._wrap_socket()
# --> 512     return self.sslsocket_class._create(
#     513         sock=sock,
#     514         server_side=server_side,
#     515         do_handshake_on_connect=do_handshake_on_connect,
#     516         suppress_ragged_eofs=suppress_ragged_eofs,
#     517         server_hostname=server_hostname,
#     518         context=self,
#     519         session=session
#     520     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1070, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1069             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1070         self.do_handshake()
#    1071 except (OSError, ValueError):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1341, in SSLSocket.do_handshake(self, block)
#    1340         self.settimeout(None)
# -> 1341     self._sslobj.do_handshake()
#    1342 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /Users/nathanwong/Desktop/Yale NUS/ResearchProject/ResearchProjectClassifier/ImageClassifierTest.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/nathanwong/Desktop/Yale%20NUS/ResearchProject/ResearchProjectClassifier/ImageClassifierTest.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/hub.py:539, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     535     raise ValueError(
#     536         f'Unknown source: "{source}". Allowed values: "github" | "local".')
#     538 if source == 'github':
# --> 539     repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, trust_repo, "load",
#     540                                        verbose=verbose, skip_validation=skip_validation)
#     542 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     543 return model
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/hub.py:180, in _get_cache_or_reload(github, force_reload, trust_repo, calling_fn, verbose, skip_validation)
#     178     os.makedirs(hub_dir)
#     179 # Parse github repo information
# --> 180 repo_owner, repo_name, ref = _parse_repo_info(github)
#     181 # Github allows branch name with slash '/',
#     182 # this causes confusion with path on both Linux and Windows.
#     183 # Backslash is not allowed in Github branch name so no need to
#     184 # to worry about it.
#     185 normalized_br = ref.replace('/', '_')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/hub.py:134, in _parse_repo_info(github)
#     129 if ref is None:
#     130     # The ref wasn't specified by the user, so we need to figure out the
#     131     # default branch: main or master. Our assumption is that if main exists
#     132     # then it's the default branch, otherwise it's master.
#     133     try:
# --> 134         with urlopen(f"https://github.com/{repo_owner}/{repo_name}/tree/main/"):
#     135             ref = 'main'
#     136     except HTTPError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)>

# %%
img = '/content/yolov5/data/images/GSAB9220.JPG'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 2880x5760 4 persons, 1 bicycle, 2 cars, 1 motorcycle, 2 traffic lights
# Speed: 288.0ms pre-process, 169.0ms inference, 0.9ms NMS per image at shape (1, 3, 320, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %% [markdown]
# # Train from Scratch

# %%
import uuid #Unique Identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('content','yolov5','data','images') #goes to the image path /content/yolov5/data/images
print(IMAGES_PATH)
labels = ['paper','no paper']
number_imgs = 644
# Out:
# content/yolov5/data/images

# %% [markdown]
# #### Loop Through Labels

# %%
for label in labels:
  print("Collecting images for {}",format(label))
  time.sleep(5)
# Out:
# Collecting images for {} paper
# Collecting images for {} no paper

# %% [markdown]
# #### Loop through images

# %%
# !git clone https://github.com/heartexlabs/labelImg.git
# Out:
# Cloning into 'labelImg'...
# remote: Enumerating objects: 2097, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2097 (delta 0), reused 4 (delta 0), pack-reused 2090
# Receiving objects: 100% (2097/2097), 237.14 MiB | 35.75 MiB/s, done.
# Resolving deltas: 100% (1245/1245), done.
